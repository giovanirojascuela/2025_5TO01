# %% [markdown]
# <a href="https://colab.research.google.com/github/giovanirojascuela/2025_5TO01/blob/Brian/TALLER/Dia%2004/PRACTICA_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PRACTICA 03 sklearn-tensorflow-numpy

# %% [markdown]
# **Ejercicio 01**

# %%
# Importación de librerías
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# Creando dataset
X = np.array([10, 11, 13, 15, 13, 12, 10, 11, 10, 15]).reshape(-1, 1)
Y = np.array([15, 16, 18, 19, 17, 16, 16, 17, 16, 20])

print(X)
print(Y)
# Out:
# [[10]
#  [11]
#  [13]
#  [15]
#  [13]
#  [12]
#  [10]
#  [11]
#  [10]
#  [15]]
# [15 16 18 19 17 16 16 17 16 20]

# %%
# Creación y ajuste del modelo
modelo = LinearRegression()
modelo.fit(X, Y)
# Out:
# LinearRegression()

# %%
# Predicción
predicciones = modelo.predict(X)

# %%
# Visualización
plt.scatter(X, Y, color='blue', label='Datos Reales')
plt.plot(X, predicciones, color='red', label='Regresión Lineal')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Regresión Lineal')
plt.legend()
plt.show()

# %%
#Evaluacion de resultado
r_sq=modelo.score(x_test, y_test)
print('coeficiente de determinación:', r_sq)
# Out:
# coeficiente de determinación: 0.0
