# %% [markdown]
# <a href="https://colab.research.google.com/github/giovanirojascuela/2025_5TO01/blob/yhonatan/TALLER/Dia%2003/%20PRACTICA_06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Crea y entrena una red neuronal con phyton y tesronflow
#
#
# 1. Cargamos y exploramos datos Fashion MINIST

# %%
from tensorflow.keras.datasets import fashion_mnist
import matplotlib.pyplot as plt
import numpy as pd
#Cargar el dataser Fasion MNIST
(X_train,Y_train),(X_test,Y_test)=fashion_mnist.load_data()
#Exploramos dataset
labels=["T-shirt/top","Trouser","Pullover","Dres","Coat","Sandal","Shirt","Sneaker","Bag","Ankle boot"]
plt.figure(figsize=(14,8))
for i in range(20):
  plt.subplot(4,5,i+1)
  plt.imshow(X_train[i],cmap="binary")
  plt.title(labels[Y_train[i]])
  plt.axis("off")
plt.show
# Out:
# ...
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# ...
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# 2. Normalizar datos

# %%
#Normalizacion
X_train,X_test=X_train/255.0,X_test/255.0

# %% [markdown]
# 3. Definicion de arquitectura de la red neuronal

# %%
from tensorflow import keras
model=keras.Sequential([
    keras.layers.Flatten(input_shape=(28,28)),
    keras.layers.Dense(128,activation='relu'),
    keras.layers.Dense(10,activation='softmax')
  ])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
#Compilar modelo
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# 4. Entrenar modelo

# %%
model.fit(X_train,Y_train,epochs=10,validation_data=(X_test,Y_test))
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.7883 - loss: 0.6239 - val_accuracy: 0.8465 - val_loss: 0.4184
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - accuracy: 0.8612 - loss: 0.3810 - val_accuracy: 0.8647 - val_loss: 0.3775
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.8753 - loss: 0.3400 - val_accuracy: 0.8621 - val_loss: 0.3795
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8844 - loss: 0.3164 - val_accuracy: 0.8720 - val_loss: 0.3544
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.8915 - loss: 0.2909 - val_accuracy: 0.8756 - val_loss: 0.3611
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.8964 - loss: 0.2804 - val_accuracy: 0.8741 - val_loss: 0.3476
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8981 - loss: 0.2729 - val_accuracy: 0.8785 - val_loss: 0.3424
# Epoch 8/10
# ...

# %%
#Evaluar modelo
test_loss,test_acc=model.evaluate(X_test,Y_test)
print('\nPresicion en el conjunto de prueba:',test_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8850 - loss: 0.3333
#
# Presicion en el conjunto de prueba: 0.8835999965667725
