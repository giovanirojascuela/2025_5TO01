# %% [markdown]
# <a href="https://colab.research.google.com/github/giovanirojascuela/2025_5TO01/blob/lau/TALLER/Dia%2003/PRACTICA_06_LAURENS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Crea y enrena una red neuronal con phyton y te tensorflow
#
# 1.Cargamos y exploramos datos Fashion MINIST

# %%
from tensorflow.keras.datasets import fashion_mnist
import matplotlib.pyplot as plt
import numpy as np
#Cargar el dataset Fasion MNIST
(X_train,Y_train),(X_test,Y_test)=fashion_mnist.load_data()
#Exploramos dataset
labels=["T-shirt/top","Trouser","Pullover","Dress","Coat","Sandal",
        "Shirt","Sneaker","Bag","Ankle boot"]
plt.figure(figsize=(14,8))
for i in range(20):
  plt.subplot(4,5,i+1)
  plt.imshow(X_train[i],cmap="binary")
  plt.title(labels[Y_train[i]])
  plt.axis("off")
plt.show()

# %% [markdown]
# # 2.Normalizar datos

# %%
#Normalizacion
X_train,X_test=X_train/255.0, X_test/255.0

# %%
from tensorflow import keras
model=keras.Sequential([
    keras.layers.Flatten(input_shape=(28,28)),
    keras.layers.Dense(128,activation='relu'),
    keras.layers.Dense(10,activation='softmax')
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
#Compilar modelo
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
#evaluar modelo
test_loss,test_acc=model.evaluate(X_test,Y_test)
print('\n Presicion en el conjunto de prueba:',test_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1157 - loss: 2.5815
#
#  Presicion en el conjunto de prueba: 0.11029999703168869
