# %% [markdown]
# <a href="https://colab.research.google.com/github/giovanirojascuela/2025_5TO01/blob/brady/TALLER/Dia%2003/PRACTICA_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #PRACTICA 03 sklearn-tensorflow-numpy

# %% [markdown]
# Ejercicio 01 - regresion lineal

# %%
# importacion de librerias
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
#creando dataset
temperatura=np.array([15,16,18,20,21,23,25,27,30,32])
ventas=np.array([500,520,560,580,600,640,680,700,760,800])
print(temperatura)
print(ventas)
# Out:
# [15 16 18 20 21 23 25 27 30 32]
# [500 520 560 580 600 640 680 700 760 800]

# %%
#dividimos los datos en conjuntos de enfrentamiento y prueba
X_train,X_test,Y_train,Y_test=train_test_split(temperatura.reshape(-1,1),
                                               ventas,test_size=0.2,
                                               random_state=42)
print("entreanmiento x---------")
print(X_train)
print("prueba x----------------")
print(X_test)
print("entrenamiento y---------")
print(Y_train)
print("prueba y----------------")
print(Y_test)
# Out:
# entreanmiento x---------
# [[23]
#  [15]
#  [27]
#  [18]
#  [32]
#  [21]
#  [20]
#  [25]]
# prueba x----------------
# [[30]
#  [16]]
# entrenamiento y---------
# [640 500 700 560 800 600 580 680]
# prueba y----------------
# [760 520]

# %%
#creamos el modelo y lo entrenamos
modelo=LinearRegression()
modelo.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
#prediccion y grafico
plt.scatter(temperatura,ventas,color="blue",label="Datos Reales")
plt.plot(temperatura,modelo.predict(temperatura.reshape(-1,1)),
         color="red",label="Regresion Lineal")
plt.xlabel("Temperatura (°C)")
plt.ylabel("Ventas")
plt.legend()
plt.show()

# %%
# evaluacion de resultado
r_sq=modelo.score(X_test,Y_test)
print("Coeficiente de determinacion (R^2):",r_sq)
# Out:
# Coeficiente de determinacion (R^2): 0.9996659605670523
