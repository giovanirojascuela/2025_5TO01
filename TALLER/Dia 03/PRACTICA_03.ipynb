# %% [markdown]
# <a href="https://colab.research.google.com/github/giovanirojascuela/2025_5TO01/blob/Brian/TALLER/Dia%2003/PRACTICA_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PRACTICA 03 sklearn-tensorflow-numpy

# %% [markdown]
# **Ejercicio 01**

# %%
# Importación de librerías
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# Creando dataset
temperatura = np.array([15, 16, 18, 20, 21, 23, 25, 27, 30, 32])
ventas = np.array([500, 520, 560, 580, 600, 640, 680, 700, 760, 800])

print(temperatura)
print(ventas)
# Out:
# [15 16 18 20 21 23 25 27 30 32]
# [500 520 560 580 600 640 680 700 760 800]

# %%
#Dividimos los datos en conjuntos de entrenamiento y prueba
x_train, x_test, y_train, y_test = train_test_split(temperatura.reshape(-1,1),
                                                    ventas, test_size=0.2,
                                                    random_state=42)
print("")
print(x_train)
print(x_train)
print(y_train)
print(y_train)
# Out:
# [[23]
#  [15]
#  [27]
#  [18]
#  [32]
#  [21]
#  [20]
#  [25]]
# [[23]
#  [15]
#  [27]
#  [18]
#  [32]
#  [21]
#  [20]
#  [25]]
# [640 500 700 560 800 600 580 680]
# [640 500 700 560 800 600 580 680]

# %%
#creamos el modelo y lo entrenamos
modelo = LinearRegression()
modelo.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
#Prediccion y grafico
plt.scatter(temperatura, ventas, color='blue', label='Datos Reales')
plt.plot(temperatura, modelo.predict(temperatura.reshape(-1,1)),
         color='red', label='Regresión Lineal')
plt.xlabel('Temperatura')
plt.ylabel('Ventas')
plt.title('Regresión Lineal de Ventas en función de la Temperatura')
plt.legend()
plt.show()

# %%
#Evaluacion de resultado
r_sq=modelo.score(x_test, y_test)
print('coeficiente de determinación:', r_sq)
# Out:
# coeficiente de determinación: 0.9996659605670523
