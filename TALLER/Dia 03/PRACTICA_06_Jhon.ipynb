# %% [markdown]
# <a href="https://colab.research.google.com/github/giovanirojascuela/2025_5TO01/blob/jhon/TALLER/Dia%2003/PRACTICA_06_Jhon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Crea y entreana una red neuronal con python y tensorflow

# %% [markdown]
# ### 1. Cargamos y exploramos datos Fashion MINIST

# %%
from tensorflow.keras.datasets import fashion_mnist
import matplotlib.pyplot as plt
import numpy as np
#cargar el dataset Fasion MINIST
(X_train,Y_train),(X_test,Y_test)=fashion_mnist.load_data()
#exporamos dataset
labels=["T-shirt/top","Trouser","Pullver","Dres","Coat","Sandal","Shirt","Sneaker","Bag","Ankle boot"]
plt.figure(figsize=(14,8))
for i in range(20):
  plt.subplot(4,5,i+1)
  plt.imshow(X_train[i],cmap="binary")
  plt.title(labels[Y_train[i]])
  plt.axis("off")
plt.show()

# %% [markdown]
# 2. Normalizar datos

# %%
#Normalizacion
X_train,X_test=X_train/255.0,X_test/255.0

# %% [markdown]
# 3.Definicion  de arquitectura de la red neuronal

# %%
from tensorflow import keras
model=keras.Sequential([
    keras.layers.Flatten(input_shape=(28,28)),
    keras.layers.Dense(128,activation="relu"),
    keras.layers.Dense(10,activation="softmax")
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
#compilar modelo
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# **4. Entrenar modelo**

# %%
model.fit(X_train,Y_train,epochs=10,validation_data=(X_test,Y_test))
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.7814 - loss: 0.6262 - val_accuracy: 0.8519 - val_loss: 0.4133
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 15s 6ms/step - accuracy: 0.8640 - loss: 0.3757 - val_accuracy: 0.8619 - val_loss: 0.3822
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.8790 - loss: 0.3357 - val_accuracy: 0.8595 - val_loss: 0.3872
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.8848 - loss: 0.3116 - val_accuracy: 0.8748 - val_loss: 0.3541
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8904 - loss: 0.2949 - val_accuracy: 0.8511 - val_loss: 0.4150
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.8951 - loss: 0.2812 - val_accuracy: 0.8746 - val_loss: 0.3523
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9023 - loss: 0.2640 - val_accuracy: 0.8681 - val_loss: 0.3600
# Epoch 8/10
# ...

# %%
#Evaluar modelo
test_loss,test_acc=model.evaluate(X_test,Y_test)
print('\nPresicion  en el conjunto de prueba:',test_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8792 - loss: 0.3459
#
# Presicion  en el conjunto de prueba: 0.8799999952316284
