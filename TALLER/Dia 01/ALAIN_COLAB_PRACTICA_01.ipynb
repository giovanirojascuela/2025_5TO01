# %% [markdown]
# <a href="https://colab.research.google.com/github/giovanirojascuela/2025_5TO01/blob/alain/TALLER/Dia%2001/ALAIN_COLAB_PRACTICA_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PRÁCTICA P1 MANIPULACIÓN BASICA DE DATOS CON PANDAS(PYTHON)

# %% [markdown]
# **Ejercicio 01 - hola mundo**

# %%
print("Hola mundo Alain")
# Out:
# Hola mundo Alain

# %% [markdown]
# **Ejercicio 02 Funciones**

# %%
def sumar(x,y):
  c=x+y
  return c

# %%
sumar(1,2)
# Out:
# 3

# %% [markdown]
# **Ejercicio 03 - dataframe**

# %%
import pandas as pd
#Creando un dataframe de undataset
df=pd.DataFrame(data={"Pais":["Mexico","Argentina","España","Colombia"],
                      "Poblacion":[127212000,45167000,47099000,48922000]})

# %%
#Mostrando Dataframe
df
# Out:
#         Pais  Poblacion
# 0     Mexico  127212000
# 1  Argentina   45167000
# 2     España   47099000
# 3   Colombia   48922000

# %%
#Ordenar columnas por variable
df.sort_values(["Pais"])
# Out:
#         Pais  Poblacion
# 1  Argentina   45167000
# 3   Colombia   48922000
# 2     España   47099000
# 0     Mexico  127212000

# %%
#Agregando columna o variable
df["Superficie"]=[1964375,2788400,505944,1142748]
df
# Out:
#         Pais  Poblacion  Superficie
# 0     Mexico  127212000     1964375
# 1  Argentina   45167000     2788400
# 2     España   47099000      505944
# 3   Colombia   48922000     1142748

# %%
#Agregar solo un valor a las tuplas de una variable
df["Deporte"]="Futbol"
df
# Out:
#         Pais  Poblacion  Superficie Deporte
# 0     Mexico  127212000     1964375  Futbol
# 1  Argentina   45167000     2788400  Futbol
# 2     España   47099000      505944  Futbol
# 3   Colombia   48922000     1142748  Futbol

# %%
#Eliminar columna o variable
df=df.drop(["Deporte"],axis=1)
df
# Out:
#         Pais  Poblacion  Superficie
# 0     Mexico  127212000     1964375
# 1  Argentina   45167000     2788400
# 2     España   47099000      505944
# 3   Colombia   48922000     1142748

# %%
df2=df
df2
#Elliminacion multiple de variables
df2.drop(["Pais","Superficie"],axis=1)
# Out:
#    Poblacion
# 0  127212000
# 1   45167000
# 2   47099000
# 3   48922000

# %%
#Numero de tuplas
cantidad_filas=len(df)
cantidad_filas
# Out:
# 4

# %%
#Agregacion de filas
df.loc[cantidad_filas]=["Venezuela",0,91164445]
df
# Out:
#         Pais  Poblacion  Superficie
# 0     Mexico  127212000     1964375
# 1  Argentina   45167000     2788400
# 2     España   47099000      505944
# 3   Colombia   48922000     1142748
# 4  Venezuela          0    91164445

# %%
#Cambio de valor de una variable
df.at[4,"Poblacion"]=[48108600]
df
# Out:
#         Pais  Poblacion  Superficie
# 0     Mexico  127212000     1964375
# 1  Argentina   45167000     2788400
# 2     España   47099000      505944
# 3   Colombia   48922000     1142748
# 4  Venezuela   48108600    91164445

# %%
#Eliminacion por celada (valor de una variable en una tupla)
df2=df
df2.drop(1,axis=0)
# Out:
#         Pais  Poblacion  Superficie
# 0     Mexico  127212000     1964375
# 2     España   47099000      505944
# 3   Colombia   48922000     1142748
# 4  Venezuela   48108600    91164445

# %% [markdown]
# **Ejercicio 02 - filtrado de dataframes**

# %%
#operadores de comparacion y logicos
#Que pais tiene mas de 47 millones
mas_de_46=df[df["Poblacion"]>48000000]
mas_de_46
# Out:
#         Pais  Poblacion  Superficie
# 0     Mexico  127212000     1964375
# 3   Colombia   48922000     1142748
# 4  Venezuela   48108600    91164445

# %%
#Filtrado con operadores logicos
df[(df["Poblacion"]>48000000)&(df["Superficie"]<6000000)]
# Out:
#        Pais  Poblacion  Superficie
# 0    Mexico  127212000     1964375
# 3  Colombia   48922000     1142748

# %%
#Filtrado por valor de variable
por_nombre=df[df["Pais"]=="Colombia"]
por_nombre
# Out:
#        Pais  Poblacion  Superficie
# 3  Colombia   48922000     1142748

# %%
#Filtrado por tamaño de valor de variable
nombre_largo=df[df["Pais"].str.len()>6]
nombre_largo
# Out:
#         Pais  Poblacion  Superficie
# 1  Argentina   45167000     2788400
# 3   Colombia   48922000     1142748
# 4  Venezuela   48108600    91164445

# %%
#Filtrado por indice
por_nombre.index.to_list()[0]
# Out:
# 3
