# %% [markdown]
# # PRACTICA 01 MANIPULACION BASICA DE DATOS CON PANDAS (PYTHON)

# %% [markdown]
# **Ejercicio 01 - hola mundo**

# %%
print("Hola mundo Brian")
# Out:
# Hola mundo Brian

# %% [markdown]
# **Ejercicio 02 funciones**

# %%
def sumar(x,y):
    c=x+y
    return c

# %%
sumar (1,2)
# Out:
# 3

# %% [markdown]
# **Ejercicio 03 - dataframe**

# %%
import pandas as pd
#Creando un dataframe de un dataset
df=pd.DataFrame(data={"Pais":["Mexico","Argentina","España","Colombia"],
                      "Poblacion":[127212000,45167000,47099000,48922000]})

# %%
#Mostrar Dataframe
df
# Out:
#         Pais  Poblacion
# 0     Mexico  127212000
# 1  Argentina   45167000
# 2     España   47099000
# 3   Colombia   48922000

# %%
#Ordenar columnas por variable
df.sort_values(["Pais"])
# Out:
#         Pais  Poblacion
# 1  Argentina   45167000
# 3   Colombia   48922000
# 2     España   47099000
# 0     Mexico  127212000

# %%
#Agregando columna o variable
df["Superficie"]=[1964375,27884000,505944,1142748]
df
# Out:
#         Pais  Poblacion  Superficie
# 0     Mexico  127212000     1964375
# 1  Argentina   45167000    27884000
# 2     España   47099000      505944
# 3   Colombia   48922000     1142748

# %%
#Agregar solo un valor a las duplas de un avariable
df["Deporte"]="Futbol"
df
# Out:
#         Pais  Poblacion  Superficie Deporte
# 0     Mexico  127212000     1964375  Futbol
# 1  Argentina   45167000    27884000  Futbol
# 2     España   47099000      505944  Futbol
# 3   Colombia   48922000     1142748  Futbol

# %%
#Eliminar columna o variable
df=df.drop(["Deporte"],axis=1)
df
# Out:
#         Pais  Poblacion  Superficie
# 0     Mexico  127212000     1964375
# 1  Argentina   45167000    27884000
# 2     España   47099000      505944
# 3   Colombia   48922000     1142748

# %%
df2=df
df2
#Eliminacion multiple de variables
df2.drop(["Pais","Superficie"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-44-bc7f734ad392> in <cell line: 0>()
#       2 df2
#       3 #Eliminacion multiple de variables
# ----> 4 df2.drop(["Pais"])
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4828                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4829             else:
# -> 4830                 new_axis = axis.drop(labels, errors=errors)
#    4831             indexer = axis.get_indexer(new_axis)
#    4832
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    7068         if mask.any():
#    7069             if errors != "ignore":
# -> 7070                 raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071             indexer = indexer[~mask]
#    7072         return self.delete(indexer)
#
# KeyError: "['Pais'] not found in axis"

# %%
#Agregacion de filas
df.loc[Cantidad_filas]=["Venezuela",0,9116445]
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-56fcf2963dcc> in <cell line: 0>()
#       1 #Agregacion de filas
# ----> 2 df.loc[Cantidad_filas]=["Venezuela",0,9116445]
#       3 df
#
# NameError: name 'Cantidad_filas' is not defined

# %%
#Cambio de valor de una variable en una tupla
df.at[4,"Poblacion"]=[48108600]
df
# Out:
#         Pais    Poblacion  Superficie
# 0     Mexico  127212000.0   1964375.0
# 1  Argentina   45167000.0  27884000.0
# 2     España   47099000.0    505944.0
# 3   Colombia   48922000.0   1142748.0
# 4        NaN   48108600.0         NaN

# %%
#Eliminacion por celda(valor de una variable en una tupla)
df2=df
df2.drop(1,axis=0)
# Out:
#        Pais  Poblacion  Superficie
# 0    Mexico  127212000     1964375
# 2    España   47099000      505944
# 3  Colombia   48922000     1142748

# %% [markdown]
# **Ejercicio 04 - filtrado de dataframe**

# %%
#Operadores de comparacion y logicos
#Que pais tiene mas de 46 millones
mas_de_46=df[df["Poblacion"]>48000000]
mas_de_46
# Out:
#        Pais    Poblacion  Superficie
# 0    Mexico  127212000.0   1964375.0
# 3  Colombia   48922000.0   1142748.0
# 4       NaN   48108600.0         NaN

# %%
#Filtrado con operadores logicos
df[(df["Poblacion"]>48000000)&(df["Superficie"]<60000000)]
# Out:
#        Pais    Poblacion  Superficie
# 0    Mexico  127212000.0   1964375.0
# 3  Colombia   48922000.0   1142748.0

# %%
#Filtrado por valor de variable
por_nombre=df[df["Pais"]=="Colombia"]
por_nombre
# Out:
#        Pais   Poblacion  Superficie
# 3  Colombia  48922000.0   1142748.0

# %%
#Filtrado por tamaño de valor de variable
nombre_largo=df
