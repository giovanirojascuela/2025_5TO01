# %%
#te amo

# %% [markdown]
# # practica 02 manipulacion de datos con pandas basica con (**python**)

# %%
print ("Hola mundo Diethmar Emerson velez")
# Out:
# Hola mundo Diethmar Emerson velez

# %%
def sumar(x,y):
  c=x+y
  return c

# %%
sumar (1,2)
# Out:
# 3

# %%
import pandas as pd

# Creando un DataFrame a partir de un diccionario
df = pd.DataFrame({
    "Pais": ["Mexico", "Argentina", "España", "Colombia"],
    "Poblacion": [127212000, 45167000, 47099000, 48922000]
})

# %%
df
# Out:
#         Pais  Poblacion
# 0     Mexico  127212000
# 1  Argentina   45167000
# 2     España   47099000
# 3   Colombia   48922000

# %%
#Ordenar Columnas por variables

df .sort_values(["Pais"])
# Out:
#         Pais  Poblacion
# 1  Argentina   45167000
# 3   Colombia   48922000
# 2     España   47099000
# 0     Mexico  127212000

# %%
#agrwgando columna  u variable

df ["Superficie"]=[19644375, 2788400, 505944,1142748]

# %%
df ["Deporte"]="Futbol"
df
# Out:
#         Pais  Poblacion  Superficie Deporte
# 0     Mexico  127212000    19644375  Futbol
# 1  Argentina   45167000     2788400  Futbol
# 2     España   47099000      505944  Futbol
# 3   Colombia   48922000     1142748  Futbol

# %%
#eliminar   columna o variable

df = df.drop(columns=["Deporte"], axis=1)
df
# Out:
#         Pais  Poblacion  Superficie
# 0     Mexico  127212000    19644375
# 1  Argentina   45167000     2788400
# 2     España   47099000      505944
# 3   Colombia   48922000     1142748

# %%
df2=df
df2
#eliminacion  multiple de variables
df2=df2.drop(["Pais","Superficie"], axis=1)
df2
# Out:
#    Poblacion
# 0  127212000
# 1   45167000
# 2   47099000
# 3   48922000

# %%
#Eliminacion por celda (valor de una nvariable en una tupla)
df2=df
df2.drop(1,axis=0)
# Out:
#        Pais  Poblacion  Superficie
# 0    Mexico  127212000    19644375
# 2    España   47099000      505944
# 3  Colombia   48922000     1142748

# %%
cantidad_filas = len(df)
df.loc[cantidad_filas] = ["Venezuela", 0, 91164445]
df
# Out:
#         Pais  Poblacion  Superficie
# 0     Mexico  127212000    19644375
# 1  Argentina   45167000     2788400
# 2     España   47099000      505944
# 3   Colombia   48922000     1142748
# 4  Venezuela          0    91164445
# 5  Venezuela          0    91164445
# 6  Venezuela          0    91164445

# %%
# Operadores de comparacion y logicos
# Que pais tiene mas de 46 millones
mas_de_46 = df[df["Poblacion"] > 46000000]

mas_de_46
# Out:
#        Pais  Poblacion  Superficie
# 0    Mexico  127212000    19644375
# 2    España   47099000      505944
# 3  Colombia   48922000     1142748

# %%
# Filtrado con operadores logicos
df[(df["Poblacion"] > 48000000) & (df["Superficie"] < 6000000)]
# Out:
#        Pais  Poblacion  Superficie
# 3  Colombia   48922000     1142748

# %%
# Filtrado por valor de variable
por_nombre=df[df["Pais"].str.len()>6]
por_nombre
# Out:
#         Pais  Poblacion  Superficie
# 1  Argentina   45167000     2788400
# 3   Colombia   48922000     1142748
# 4  Venezuela          0    91164445
# 5  Venezuela          0    91164445
# 6  Venezuela          0    91164445

# %%
# Filtracion por tamaño de variable
nombre_largo=df[df["Pais"].str.len()>6]
nombre_largo
# Out:
#         Pais  Poblacion  Superficie
# 1  Argentina   45167000     2788400
# 3   Colombia   48922000     1142748
# 4  Venezuela          0    91164445
# 5  Venezuela          0    91164445
# 6  Venezuela          0    91164445

# %%
# Filtrado por indice
por_nombre.index.
