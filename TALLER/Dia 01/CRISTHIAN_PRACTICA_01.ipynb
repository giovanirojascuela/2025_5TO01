# %% [markdown]
# # PRACTICA 01 MANIPULACIOn DE DATOS CON PANDAS (PYTHON)

# %% [markdown]
# # Ejercicio 01-hola mundo

# %%
print("Hola mundo Cristhian")
# Out:
# Hola mundo Cristhian

# %% [markdown]
# **Ejercicio 02 - funciones**

# %%
def sumar(x,y):
  c=x+y
  return c

# %%
sumar(1,2)
# Out:
# 3

# %% [markdown]
# **Ejercicio 03 - dataframe**

# %%
import pandas as pd
#Creando un dataframe de un dataset
df=pd.DataFrame(data={"Pais":["Mexico","Argentina","España","Colombia"],
                      "Poblacion":[127212000,45167000,47099000,48922000]})

# %%
#Mostrar Dataframe
df
# Out:
#         Pais  Poblacion
# 0     Mexico  127212000
# 1  Argentina   45167000
# 2     España   47099000
# 3   Colombia   48922000

# %%
#Ordenar columnas por variable
df.sort_values(["Pais"])
# Out:
#         Pais  Poblacion
# 1  Argentina   45167000
# 3   Colombia   48922000
# 2     España   47099000
# 0     Mexico  127212000

# %%
#Agregando columna o variable
df["Superficie"]=[1964375,2788400,505944,1142748]
df
# Out:
#         Pais  Poblacion  Superficie
# 0     Mexico  127212000     1964375
# 1  Argentina   45167000     2788400
# 2     España   47099000      505944
# 3   Colombia   48922000     1142748

# %%
#Agregar solo un valor a las tuplas de una variable
df["Deporte"]="Futbol"
df
# Out:
#         Pais  Poblacion  Superficie Deporte
# 0     Mexico  127212000     1964375  Futbol
# 1  Argentina   45167000     2788400  Futbol
# 2     España   47099000      505944  Futbol
# 3   Colombia   48922000     1142748  Futbol

# %%
#Eliminar columna o variable
df=df.drop(["Deporte"],axis=1)
df
# Out:
#         Pais  Poblacion  Superficie
# 0     Mexico  127212000     1964375
# 1  Argentina   45167000     2788400
# 2     España   47099000      505944
# 3   Colombia   48922000     1142748

# %%
df2=df
df2
#Eliminacion multiple de variables
df2.drop(["Pais","Superficie"],axis=1)
# Out:
#    Poblacion
# 0  127212000
# 1   45167000
# 2   47099000
# 3   48922000

# %%
#Numero de tuplas
Cantidad_filas=len(df)
Cantidad_filas
# Out:
# 4

# %%
#Agregacion de filas
df.loc[len(df)] = ["Chile", 19000000, 756102]

# %%
#Cambio de valor de una variable en tupla
df.loc[df["Pais"] == "Mexico", "Poblacion"] = 130000000

# %%
#Eliminacion por celda (valor de una variable en una tupla)
df=df
df2.drop(1,axis=0)
# Out:
#        Pais  Poblacion  Superficie
# 0    Mexico  130000000     1964375
# 2    España   47099000      505944
# 3  Colombia   48922000     1142748
# 4     Chile   19000000      756102

# %%
#Operaciones de comparacion y logicos
#que pais tiene mas de 46 millones
mas_de_46=df[df["Poblacion"]>48000000]
mas_de_46
# Out:
#        Pais  Poblacion  Superficie
# 0    Mexico  130000000     1964375
# 3  Colombia   48922000     1142748

# %%
#filtrado por vaolor de variable
por_nombre=df[df["Pais"]=="Colombia"]
por_nombre
# Out:
#        Pais  Poblacion  Superficie
# 3  Colombia   48922000     1142748

# %%
#filtrado por tamaño de valor de variable"
df_filtrado = df[df["Pais"].str.len() > 6]
print(df_filtrado)
# Out:
#         Pais  Poblacion  Superficie
# 1  Argentina   45167000     2788400
# 3   Colombia   48922000     1142748
