# %% [markdown]
# <a href="https://colab.research.google.com/github/giovanirojascuela/2025_5TO01/blob/Brenda/TALLER/Dia%2002/PRACTICA03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# PRACTICA 03 SKLEARN-TENSORFLOW -NUMPY

# %% [markdown]
# EJERCICIO 01 -REGRESION LINEAL

# %%
#importacion de librerias
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
#CREANDO UN DATASET
temperatura=np.array([15,16,18,20,21,23,25,30,32])
# Removed the last element (800) from the ventas array to match the length of temperatura
ventas=np.array([500,520,560,580,600,620,650,700,760,800])
print(temperatura)
print (ventas)

# %%
# DIVIDIMOS LOS DATOS EN COJUNTO DE ENTRENAMIENTO  Y PRUEBAS
X_train,X_test,y_train,y_test=train_test_split(temperatura.reshape(-1,1),
                                               ventas,test_size=0.2,
                                               random_state=42)
print("Entrenamiento x-----------------------")
print(X_train)
print("prueba x--------------------------------")
print(X_test)
print("Entrenamiento y-----------------------")
print(y_train)
print("Prueba Y-------------------------------")
print(y_test)
# Out:
# Entrenamiento x-----------------------
# [[23]
#  [15]
#  [32]
#  [18]
#  [21]
#  [20]
#  [25]]
# prueba x--------------------------------
# [[30]
#  [16]]
# Entrenamiento y-----------------------
# [620 500 760 560 600 580 650]
# Prueba Y-------------------------------
# [700 520]

# %%
#CREAMOS EL MODELO Y LO ENTRENAMOS
model=LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
#PREDICCION Y GRAFICOS
plt.scatter(temperatura,ventas,color="blue",label="Datos Reales")
plt.plot(temperatura,model.predict(temperatura.reshape(-1,1)),
         color="red",label="Linea de Regresion")
plt.xlabel("Temperatura (°C)")
plt.ylabel("Ventas")
plt.title("Regresion Lineal")
plt.legend()
plt.show()

# %%
#EVALUACION  DE RESULTADO
r_sq=model.score(X_test,y_test)
print("Coeficiente de Determinacion",r_sq)
# Out:
# Coeficiente de Determinacion 0.9492112482853226
