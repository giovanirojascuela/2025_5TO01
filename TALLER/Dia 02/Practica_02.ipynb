# %% [markdown]
# <a href="https://colab.research.google.com/github/giovanirojascuela/2025_5TO01/blob/LuisDevInger/TALLER/Dia%2002/Practica_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PRACTICA 02 GRAFICOS CON PANDAS(PYTHON)

# %% [markdown]
# **Ejercicio 01 - Histogramas y otros**

# %%
import pandas as pd

# Crando un dataframe de un dataset de la practica 01
df=pd.DataFrame(data={"Pais":["Mexico","Argentina","España","Colombia"],
                      "Poblacion":[127212000,45167000,47099000,48922000]})

df["Superficie"]=[1964375,2788400,505944,1142748]
cantidad_filas=len(df)
df.loc[cantidad_filas]=["Venezuela",0,9116445]
df.at[4,"Poblacion"]=[48108600]
df
# Out:
#         Pais  Poblacion  Superficie
# 0     Mexico  127212000     1964375
# 1  Argentina   45167000     2788400
# 2     España   47099000      505944
# 3   Colombia   48922000     1142748
# 4  Venezuela   48108600     9116445

# %%
# Preparacion de dataframe
# Agregando variable radio de habitante por superficie

df["habitxkm2"]=(df["Poblacion"]/df["Superficie"]).astype(int)
df.sort_values(["habitxkm2"])
# Out:
#         Pais  Poblacion  Superficie  habitxkm2
# 4  Venezuela   48108600     9116445          5
# 1  Argentina   45167000     2788400         16
# 3   Colombia   48922000     1142748         42
# 0     Mexico  127212000     1964375         64
# 2     España   47099000      505944         93

# %%
# importar libreria matplolib
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df[["Poblacion","Superficie"]].plot.hist(bins=20,alpha=0.5)
# Out:
# <Axes: ylabel='Frequency'>

# %%
# Grafico de barras
df.set_index("Pais")["Poblacion"].plot(kind="bar")
# Out:
# <Axes: xlabel='Pais'>

# %%
# Grafico de area
df.set_index("Pais")["habitxkm2"].plot(kind="area")
# Out:
# <Axes: xlabel='Pais'>

# %%
# Grafico de pastel
df.set_index("Pais")["Superficie"].plot(kind="pie")
# Out:
# <Axes: ylabel='Superficie'>
