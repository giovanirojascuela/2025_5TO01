# %% [markdown]
# <a href="https://colab.research.google.com/github/giovanirojascuela/2025_5TO01/blob/jhon/TALLER/Dia%2002/Practica_04_jhon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importacion de librerias
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
#creando dataset
x=np.array([10,11,13,15,13,12,10,11,15,10])
y=np.array([15,16,18,19,17,16,16,17,20,16])
print(x)
print(y)
# Out:
# [10 11 13 15 13 12 10 11 15 10]
# [15 16 18 19 17 16 16 17 20 16]

# %%
X_train,X_test, Y_train, Y_test=train_test_split(x.reshape(-1,1),y,test_size=0.2,random_state=42)
modelo=LinearRegression()
modelo.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
plt.scatter(x,y,color="blue",label="Datos Reales")
plt.plot(x,modelo.predict(x.reshape(-1,1)),color="red",label="Linear de Regresion")
plt.xlabel("x (C°)")
plt.ylabel("y")
plt.legend()
plt.show()
