# %% [markdown]
# <a href="https://colab.research.google.com/github/giovanirojascuela/2025_5TO01/blob/Jheny/TALLER/Dia%2002/Practica_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importar librerías necesarias
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Datos extraídos de la imagen
x = np.array([10, 11, 13, 15, 13, 12, 10, 11, 15, 10]).reshape(-1, 1)
y = np.array([15, 16, 18, 19, 17, 16, 16, 17, 20, 16])

# %%
# Crear el modelo de regresión lineal
modelo = LinearRegression()

# Entrenar el modelo con los datos
modelo.fit(x, y)

# Mostrar coeficientes
print("Coeficiente (pendiente):", modelo.coef_[0])
print("Intersección (ordenada al origen):", modelo.intercept_)
# Out:
# Coeficiente (pendiente): 0.7352941176470585
# Intersección (ordenada al origen): 8.176470588235297

# %%
# Predecir valores
y_pred = modelo.predict(x)

# Mostrar predicciones
for xi, yi in zip(x.flatten(), y_pred):
    print(f"x = {xi} -> y estimado = {yi:.2f}")
# Out:
# x = 10 -> y estimado = 15.53
# x = 11 -> y estimado = 16.26
# x = 13 -> y estimado = 17.74
# x = 15 -> y estimado = 19.21
# x = 13 -> y estimado = 17.74
# x = 12 -> y estimado = 17.00
# x = 10 -> y estimado = 15.53
# x = 11 -> y estimado = 16.26
# x = 15 -> y estimado = 19.21
# x = 10 -> y estimado = 15.53

# %%
# Graficar puntos y línea de regresión
plt.scatter(x, y, color='blue', label='Datos originales')
plt.plot(x, y_pred, color='red', label='Línea de regresión')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Regresión Lineal')
plt.legend()
plt.grid(True)
plt.show()
