# %% [markdown]
# <a href="https://colab.research.google.com/github/giovanirojascuela/2025_5TO01/blob/RenaII/TALLER/Dia%2002/Practica_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importacion de librerias
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
#creando dataset
temperatura=np.array([10,11,13,15,13,12,10,11,15,10])
ventas=np.array([15,16,18,19,17,16,16,17,20,16])
print(temperatura)
print(ventas)
# Out:
# [10 11 13 15 13 12 10 11 15 10]
# [15 16 18 19 17 16 16 17 20 16]

# %%
##dividimos los datos en conjunto de entrenamiento y prueba
X_train, X_test, Y_train, Y_test=train_test_split(temperatura.reshape(-1,1),ventas,test_size=0.2,random_state=42)
print("EntrenamientoX------------")
print(X_train)
print("E-X-----------------------")
print(X_test)
print("E-X-----------------------")
print(Y_train)
print("E-Y-----------------------")
print(Y_test)
print("E-Y-----------------------")
# Out:
# EntrenamientoX------------
# [[12]
#  [10]
#  [11]
#  [13]
#  [10]
#  [13]
#  [15]
#  [10]]
# E-X-----------------------
# [[15]
#  [11]]
# E-X-----------------------
# [16 15 17 18 16 17 19 16]
# E-Y-----------------------
# [20 16]
# E-Y-----------------------

# %%
#Creamos el modelo y lo entrenamos
modelo=LinearRegression()
modelo.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
plt.scatter(temperatura,ventas,color="blue",label="Datos Reales")
plt.plot(temperatura,modelo.predict(temperatura.reshape(-1,1)),
         color="red",label="Lina de regresion")
plt.xlabel("Practica 04")
plt.ylabel("Practica 04")
plt.legend()
plt.show()

# %%
#EVALUACION DE RESULTADOS
r_sq=modelo.score(X_test,Y_test)
print("Coeficiente de determinacion",r_sq)
# Out:
# Coeficiente de determinacion 0.7960332729741965
