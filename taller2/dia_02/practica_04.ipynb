# %% [markdown]
# <a href="https://colab.research.google.com/github/giovanirojascuela/2025_5TO01/blob/andres/taller2/dia_02/practica_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# practica_04
# realice la construcion del modelo
# entrenamientoy grafico de regresion lineal con los
# siguientes datos:
# x 10, 11, 13, 15, 13, 12, 10, 11, 15, 10
# y 15, 16, 18, 19, 17, 16, 16, 17, 20, 16

# %%
#importacion de lobrerias
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
#creando dataset
X = np.array([10, 11, 13, 15, 13, 12, 10, 11, 15, 10])
Y = np.array([15, 16, 18, 19, 17, 16, 16, 17, 20, 16])
print(X)
print(Y)
# Out:
# [10 11 13 15 13 12 10 11 15 10]
# [15 16 18 19 17 16 16 17 20 16]

# %%
# dividimos los datos en conjuntos de entrenamiento y pruebas
X_train, X_test, Y_train, Y_test=train_test_split(X.reshape(-1,1),
                                                  Y,test_size=0.2,
                                                  random_state=42)
print("entrenamiento X_______________________")
print(X_train)
print("prueba x_____________________________")
print(X_test)
print("entrenamiento Y_____________________")
print(Y_train)
print("prueba Y________________________")
print("Y_test")
# Out:
# entrenamiento X_______________________
# [[12]
#  [10]
#  [11]
#  [13]
#  [10]
#  [13]
#  [15]
#  [10]]
# prueba x_____________________________
# [[15]
#  [11]]
# entrenamiento Y_____________________
# [16 15 17 18 16 17 19 16]
# prueba Y________________________
# Y_test

# %%
# creamos el modelo y lo entrenamremos
modelo=LinearRegression()
modelo.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
# Mostramos coeficientes
print("Coeficiente (pendiente):", modelo.coef_[0])
print("Intersección:", modelo.intercept_)
# Out:
# Coeficiente (pendiente): 0.6170212765957447
# Intersección: 9.5

# %%
# Graficamos los datos y la línea de regresión
# prediccion y grafico
plt.scatter(X,Y,color="blue",label="datos reales")
plt.plot(X,modelo.predict(X.reshape(-1,1)),color="red",label="linea de regresion")
plt.xlabel("temperatura(°c)")
plt.ylabel("ventas")
plt.legend()
plt.show()
