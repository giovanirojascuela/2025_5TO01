# %% [markdown]
# <a href="https://colab.research.google.com/github/giovanirojascuela/2025_5TO01/blob/andres/taller/dia_02/practica_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ejercicios 01 - histogramas y otros

# %%
import pandas as pd
# creando un data frame d un data sel
df=pd.DataFrame(data={"pais":["mexico","argentina","españa","colombia"],
                      "poblacion":[127865000,45987623,448922000,47099000]})
df[ "Superficie"]=[1964375,2788400,505944,1142748]
Cantidad_filas=len(df)
df.loc[Cantidad_filas]=["venezuela",0,9116445]
df.at[4,"poblacion"]=[48108600]
df
# Out:
#         pais  poblacion  Superficie
# 0     mexico  127865000     1964375
# 1  argentina   45987623     2788400
# 2     españa  448922000      505944
# 3   colombia   47099000     1142748
# 4  venezuela   48108600     9116445

# %%
# preparacion con data frame
#agregando variables radio de habitants por superficie
df["habitxkm2"]=(df["poblacion"]/df["Superficie"]).astype(int)
df.sort_values(["habitxkm2"])
# Out:
#         pais  poblacion  Superficie  habitxkm2
# 4  venezuela   48108600     9116445          5
# 1  argentina   45987623     2788400         16
# 3   colombia   47099000     1142748         41
# 0     mexico  127865000     1964375         65
# 2     españa  448922000      505944        887

# %%
#grafico de barras

df.set_index("pais")["poblacion"].plot(kind="bar")
# Out:
# <Axes: xlabel='pais'>

# %%
# grafico de area
df.set_index("pais")["habitxkm2"].plot(kind="area")
# Out:
# <Axes: xlabel='pais'>

# %%
# grafico de pastel

df.set_index("pais")["Superficie"].plot(kind="pie")
# Out:
# <Axes: ylabel='Superficie'>
