# %% [markdown]
# <a href="https://colab.research.google.com/github/giovanirojascuela/2025_5TO01/blob/brady/PRACTICA01_BRADY_COLAB_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PRACTICA 01 MANIPULACION BASICA DE DATOS CON PANDAS (PYTHON)

# %% [markdown]
# Ejecicio 01. hola mundo

# %%
print ('hola mundo BRADY')
# Out:
# hola mundo BRADY

# %% [markdown]
# Ejercicip 02. funciones

# %%
def sumar(x,y):
  c=x+y
  return c

# %%
sumar (1,2)
# Out:
# 3

# %% [markdown]
# Ejercicio 03 . dataframe

# %%
import pandas as pd
# creando un datafrema a partir de un diccionario
df = pd.DataFrame({
    "Pais": ["Brazil", "Argentina", "Portugal", "Peru"],
    "poblacion": [1234323, 134234543, 344354645, 12423423]
})

# %%
df
# Out:
#         Pais  poblacion
# 0     Brazil    1234323
# 1  Argentina  134234543
# 2   Portugal  344354645
# 3       Peru   12423423

# %%
# ordenar columnas por varialbes
df.sort_values(by="Pais")
# Out:
#         Pais  poblacion
# 1  Argentina  134234543
# 0     Brazil    1234323
# 3       Peru   12423423
# 2   Portugal  344354645

# %%
df ["Superficie"]=[1234323, 134234543, 344354645, 12423423]

# %%
df["Deporte"]="Futbol"
df
# Out:
#         Pais  poblacion  Superficie Deporte
# 0     Brazil    1234323     1234323  Futbol
# 1  Argentina  134234543   134234543  Futbol
# 2   Portugal  344354645   344354645  Futbol
# 3       Peru   12423423    12423423  Futbol

# %%
#eliminar columna o variable
df = df.drop(columns=["Deporte"],axis=1)
df
# Out:
#         Pais  poblacion  Superficie
# 0     Brazil    1234323     1234323
# 1  Argentina  134234543   134234543
# 2   Portugal  344354645   344354645
# 3       Peru   12423423    12423423

# %%
df2=df
df2
#eliminacion multiple de variable
df2=df2.drop(["Pais","Superficie"],axis=1)
df2
# Out:
#    poblacion
# 0    1234323
# 1  134234543
# 2  344354645
# 3   12423423

# %%
# agregar una nueva fila
df.loc[len(df)] = ["Venezuela", 91164445, 916445]
df
# Out:
#         Pais  poblacion  Superficie
# 0     Brazil    1234323     1234323
# 1  Argentina  134234543   134234543
# 2   Portugal  344354645   344354645
# 3       Peru   12423423    12423423
# 4  Venezuela   91164445      916445

# %%
#eliminacion por celda (vlor de unavariable en una dupla)
df2=df
df2.drop(1,axis=0)
# Out:
#         Pais  poblacion  Superficie
# 0     Brazil    1234323     1234323
# 2   Portugal  344354645   344354645
# 3       Peru   12423423    12423423
# 4  Venezuela   91164445      916445
